# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("can_signals_by_second.csv")  # Replace with your filename

# Display the last few rows
df.tail(20)
# Out:
#      Second    acc0     acc1  accumulator_fans_current  auto_breaking_voltage  \
# 200     244  2959.0  35584.0                     153.0                    0.0
# 201     245  2962.0  14337.0                     153.0                    0.0
# 202     246  2961.0  39936.0                     153.0                    0.0
# 203     247  2958.0  10241.0                     153.0                    0.0
# 204     248  2958.0  21248.0                     153.0                    0.0
# 205     249  2962.0  23040.0                     152.0                    0.0
# 206     250  2960.0  23040.0                     153.0                    0.0
# 207     251  2962.0  53760.0                     152.0                    0.0
# 208     252  2960.0  23040.0                     152.0                    0.0
# 209     253  2961.0    769.0                     153.0                    0.0
# 210     254  2960.0    769.0                     153.0                    0.0
# ...

# %%
df = df.drop(['accumulator_fans_current',
       'auto_breaking_voltage', 'auto_steering_voltage', 'b1_ready_to_drive',
       'b2_data_logging', 'b3', 'b4', 'buzzer_state', 'radiator_fans_current', 
       's1_coolant_pump', 's2_radiator_fan', 's3_accumulator_fan', 'lidar_current',
       'error0',
       'error1', 'error10', 'error11', 'error12', 'error13', 'error14',
       'error15', 'error16', 'error17', 'error18', 'error19', 'error2',
       'error20', 'error21', 'error22', 'error23', 'error24', 'error25',
       'error26', 'error27', 'error28', 'error29', 'error3', 'error30',
       'error31', 'error32', 'error33', 'error34', 'error35', 'error36',
       'error37', 'error38', 'error39', 'error4', 'error40', 'error41',
       'error42', 'error43', 'error44', 'error45', 'error46', 'error47',
       'error48', 'error49', 'error5', 'error50', 'error51', 'error52',
       'error53', 'error54', 'error55', 'error56', 'error57', 'error58',
       'error59', 'error6', 'error60', 'error61', 'error62', 'error63',
       'error7', 'error8', 'error9', 'flags', 'gpio_sense', 'coolant_pump_current', 'bms_fault', 'ping_lv_nodes',
       'speed_mode_enabled', 'speed_signal', 'torque_signal_small', 'command_torque_limited', 'direction_value', 'lv_current'], axis=1)

# %%
df.columns
# Out:
# Index(['Second', 'acc0', 'acc1', 'bms_state', 'brake1_psi', 'brake2_psi',
#        'brake_percent', 'bus_voltage', 'current', 'imd_fault',
#        'inverter_dicharge', 'inverter_enable', 'relay_state',
#        'shutdown_voltage', 'voltage'],
#       dtype='object')

# %%
df.tail(20)
# Out:
#      Second    acc0     acc1  bms_state  brake1_psi  brake2_psi  \
# 200     244  2959.0  35584.0        4.0       198.0       392.0
# 201     245  2962.0  14337.0        4.0       270.0       570.0
# 202     246  2961.0  39936.0        4.0       208.0       412.0
# 203     247  2958.0  10241.0        4.0       270.0       552.0
# 204     248  2958.0  21248.0        4.0       180.0       332.0
# 205     249  2962.0  23040.0        4.0        68.0        89.0
# 206     250  2960.0  23040.0        4.0        70.0        89.0
# 207     251  2962.0  53760.0        4.0       126.0       195.0
# 208     252  2960.0  23040.0        4.0        70.0        90.0
# 209     253  2961.0    769.0        4.0       422.0       771.0
# 210     254  2960.0    769.0        4.0       442.0       771.0
# 211     255  2960.0  19201.0        4.0       309.0       586.0
# 212     256  2959.0  11521.0        5.0       289.0       558.0
# 213     257  2960.0   4097.0        5.0       273.0       527.0
# ...
